# %%
print('Hello world')
# Out:
# Hello world

# %%
a = 3
b = 5
c = a + b
print('The result is ', c)
# Out:
# The result is  8

# %%
print('Twinkle, twinkle, little star,')
print('\t How wonder what your are!')
print('\t\t Up above the world so high,')
print('\t\t Like a diamond in the sky')
print('Twinkle, twinkle, little star,')
print('\t How wonder what your are!')
# Out:
# Twinkle, twinkle, little star,
# 	 How wonder what your are!
# 		 Up above the world so high,
# 		 Like a diamond in the sky
# Twinkle, twinkle, little star,
# 	 How wonder what your are!

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]

# %%
from datetime import date
today = date.today()
print('Today\'s date is ', today)
# Out:
# Today's date is  2022-01-01

# %%
import datetime
now = datetime.datetime.now()
print('Now date and time is ')
print(now.strftime('%y-%m-%d  %H:%M:%S'))
# Out:
# Now date and time is
# 22-01-01  09:08:57

# %%
from math import pi
r = float(input('Enter the readius of the circule: '))
calArea = str(pi * r**2);
print('The area of the circule with radius '  + str(r) + ' is' + calArea)
# Out:
# Enter the readius of the circule: 2
# The area of the circule with radius 2.0 is12.566370614359172

# %%
fname = input('Enter your first name')
lname = input('Enter your last name ')
fullname = fname + " " + lname;
#print('Your full name is '+ fullname)
print('Your full name in reverse  '+ fullname [::-1])
# Out:
# Enter your first nameRafi
# Enter your last name Ullah
# Your full name in reverse  hallU ifaR

# %%
a = int(input('Enter a number 1 '))
b = int(input('Enter number 2 '))
c = (a + b);
print('The sum of {0} and {1} is {2}'.format(a,b,c))
# Out:
# Enter a number 1 12
# Enter number 2 12
# The sum of 12 and 12 is 24
